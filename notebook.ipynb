# %%
import pandas as pd 
import pyEX as p


print(p.chart)
# c = p.Client(api_token="pk_6ff6a3397f864fa99013ac76f64173c6")
c = p.Client(api_token="pk_6ff6a3397f864fa99013ac76f64173c6")
# cs = p.Client(version='sandbox')
# Out:
# <function chart at 0x000001F82476C8B0>

# %%
aple_df = pd.read_csv('./dataset/AAPL_July.csv')
# Out:
#          date minute  label     open     high     low    close     average  \
# 0  2020-07-02  09:30  09:30  367.845  370.470  367.45  369.955  369.297299
# 1  2020-07-02  10:00  10:00  369.900  370.010  365.74  366.010  368.548898
# 2  2020-07-02  10:30  10:30  366.120  368.020  366.12  367.100  367.121691
# 3  2020-07-02  11:00  11:00  367.175  367.175  366.05  366.260  366.688094
# 4  2020-07-02  11:30  11:30  366.390  367.430  365.85  367.360  366.692708
#
#    volume      notional  numberOfTrades  marketOpen  marketHigh  marketLow  \
# 0   68445  2.527655e+07             345     367.850      370.47     367.33
# 1   19574  7.213978e+06             203     369.990      370.08     365.50
# 2    8663  3.180376e+06             122     366.145      368.08     365.92
# 3    5476  2.007984e+06              83     367.230      367.27     365.89
# 4   13299  4.876646e+06              88     366.400      367.54     365.81
#
#    marketClose  marketAverage  marketVolume  marketNotional  \
# 0      369.980     369.284370       4535286    1.674811e+09
# 1      366.160     368.163823       2810829    1.034846e+09
# 2      367.231     367.088295       2076576    7.622868e+08
# 3      366.355     366.615122       1280133    4.693162e+08
# 4      367.440     366.653429       1132975    4.154092e+08
#
#    marketNumberOfTrades
# 0                 20503
# 1                 12629
# 2                  9569
# 3                  6360
# 4                  5794

# %%
fdf['%change_next'].hist()
# Out:
# <AxesSubplot:>

# %%
fdf = pd.read_csv('dataset.csv')
fdf['%change_next'].plot()
fdf['%change'].plot()
fdf['%change_prev'] = fdf['%change'].shift(-1)

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = (20,5)
# plt.plot(run_df[run_df.index=='2020-07-27']['open'].values)
mv  = run_df_daily['marketVolume'].values
plt.plot(mv / np.max(mv))
# plt.show()
iexv = run_df_daily['volume'].values
plt.plot(iexv / np.max(iexv))
plt.show()

plt.plot(run_df_daily['high'].values[:50])
plt.plot(run_df_daily['marketHigh'].values[:50])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-d5826f91f247> in <module>
#       4 mpl.rcParams['figure.figsize'] = (20,5)
#       5 # plt.plot(run_df[run_df.index=='2020-07-27']['open'].values)
# ----> 6 mv  = run_df_daily['marketVolume'].values
#       7 plt.plot(mv / np.max(mv))
#       8 # plt.show()
#
# NameError: name 'run_df_daily' is not defined

# %%
from datetime import date
today = date.today()
csv_name = './dataset/RUN' + str(today) + '.csv'
run_df_daily.to_csv(csv_name)

# %%
tempdf = c.newsDF('RUN')

# %%
tempdf.iloc[0]['image']
# Out:
# 'https://cloud.iexapis.com/v1/news/image/5f9fcf47-f07a-4bc9-8fa0-681af6ace0b6'

# %%
date.today().month
# Out:
# 8

# %%
import pandas as pd 
import os
import glob
import datetime
import numpy as np
from collections import defaultdict
from scipy.special import softmax
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = (20,5)

class Acount:
    def __init__(self, cash=1000):
        self.cash = cash
        self.positions =  defaultdict(int)
        self.n_trades = 0
    def buy(self, sym, N, price):
        cash_needed = price * N
        if self.cash < cash_needed:
            N = 0
            # print('Not enough cash to buy {}  of {} ({} needed, cash balanace: ${}'.format(N, sym, round(cash_needed, 2), round(self.cash,2)))
        else:
            self.positions[sym] += N
            self.cash -= cash_needed
            self.n_trades += 1
            # print('Bought {}  of {}, spent {}, new cash balance: ${}'.format(N, sym, round(cash_needed, 2), round(self.cash)))
    
    def sell(self, sym, N, price):
        cash_value = price * N
        if self.positions[sym] < N:
            N = N
            # print('Requested to sell {} of {}, but only have {}'.format(N, sym, self.positions[sym]))
        else:
            self.positions[sym] -= N
            self.cash += cash_value
            self.n_trades += 1
            # print('Sold {}  of {}, gained {}, new cash balance: ${}'.format(N, sym, cash_value, round(self.cash, 2)))
       
    def get_total_assets(self):
        return 


def buy_decision(df_s, cash):
    # df_s.sort_values(by=['%change'], ascending=False)
    df_s['rand'] =  np.random.randint(1, 100, df_s.shape[0])
    df_s = df_s[df_s['%change'] > 0.02]
    if len(df_s):
        df_s['weight'] = softmax(df_s['%change'].values)
        df_s['cash_per_sym'] = df_s['weight'] * cash / 3
        df_s['N_buy'] = np.round(df_s['cash_per_sym'] / df_s['trdingPrice'])
        df_s = df_s[df_s['N_buy']>0]
        return list(zip(df_s.sym, df_s.N_buy, df_s.trdingPrice))
    else:
        return []

def sell_decision(df_s, acc):
    # df_s.sort_values(by=['%change'], ascending=False)
    df_s['N_sell'] = df_s['sym'].apply(lambda x: acc.positions[x])
    df_s = df_s[df_s['N_sell']>0]
    return list(zip(df_s.sym, df_s.N_sell, df_s.trdingPrice))




my_acc = Acount(5000)
# my_acc.buy('AAPL', 10, 22)
print(my_acc.positions)


df = pd.read_csv('normalized_dataset.csv', index_col=0)
df.reset_index(drop=True, inplace=True)
df = df[df['sym']!='TSLA']
df = df[df['sym']!='AAPL']
df = df[df['sym']!='RUN']


print(len(df))
df = df.dropna()
print(len(df))
df = df.sort_values(by=['date'])
times_list = df['date'].unique()
acc_val_history = []
cass_history = []
k = 0
for t in times_list:
    if '00' in t or '30' in t:
        cur_df = df[(df['date']==t)]



        order_list = buy_decision(cur_df, my_acc.cash)
        for order in order_list:
            my_acc.buy( order[0], order[1], order[2])

        sell_df = df[(df['date']==t) & (df['%change'] < - 0.02)].copy()
        order_list = sell_decision(sell_df, my_acc)
        for order in order_list:
            my_acc.sell( order[0], order[1], order[2])
        
        acc_val = round(my_acc.cash  + np.sum([N * cur_df[cur_df['sym']==sym]['trdingPrice'] for sym, N in my_acc.positions.items()]), 1)
    
        pos_={k: v for k, v in my_acc.positions.items() if v}
        print(t, pos_, 'acc_val = ', acc_val)

    acc_val = round(my_acc.cash  + np.sum([N * cur_df[cur_df['sym']==sym]['trdingPrice'] for sym, N in my_acc.positions.items()]), 1)
    acc_val_history.append(acc_val)
    cass_history.append(my_acc.cash)

    k = (k+1) % 1


plt.plot(acc_val_history)
# plt.plot(cass_history)
plt.xticks(range(0,len(times_list)), times_list,  rotation = 'vertical')
plt.gca().xaxis.set_major_locator(plt.MultipleLocator(10))
plt.show()
print(my_acc.n_trades)
# Out:
# , 'UBER': 5.0, 'FSLY': 2.0, 'QQQ': 2.0, 'NET': 2.0} acc_val =  5294.3
# 2020-08-18 14:30 {'FB': 1.0, 'SPY': 1.0, 'MSFT': 1.0, 'UBER': 9.0, 'QQQ': 2.0} acc_val =  5293.8
# 2020-08-18 15:00 {'FB': 2.0, 'AMD': 1.0, 'MSFT': 1.0, 'UBER': 15.0, 'MSI': 1.0, 'FSLY': 2.0, 'QQQ': 2.0, 'NET': 2.0} acc_val =  5297.2
# 2020-08-18 15:30 {'MSI': 2.0, 'FSLY': 7.0, 'NET': 5.0} acc_val =  5294.5
# 2020-08-19 09:30 {'UAL': 38.0} acc_val =  5279.3
# 2020-08-19 10:00 {'AMD': 1.0, 'MSI': 1.0, 'FSLY': 1.0, 'NET': 10.0} acc_val =  5265.6
# 2020-08-19 10:30 {'FB': 2.0, 'SPY': 1.0, 'COF': 4.0, 'MSI': 1.0, 'QQQ': 1.0, 'NET': 10.0} acc_val =  5264.9
# 2020-08-19 11:00 {'SPY': 1.0, 'MSFT': 1.0, 'FSLY': 7.0, 'QQQ': 1.0, 'NET': 16.0} acc_val =  5264.8
# 2020-08-19 11:30 {'SPY': 1.0, 'AMD': 1.0, 'MSFT': 1.0, 'FSLY': 8.0, 'QQQ': 1.0, 'NET': 18.0} acc_val =  5268.9
# 2020-08-19 12:00 {'COF': 4.0, 'UBER': 10.0, 'UAL': 12.0} acc_val =  5261.6
# 2020-08-19 12:30 {'MSFT': 1.0, 'FSLY': 8.0, 'NET': 5.0} acc_val =  5258.7
# 2020-08-19 13:00 {'COF': 1.0, 'AMD': 1.0, 'UBER': 3.0, 'MSI': 1.0, 'FSLY': 17.0, 'NET': 7.0} acc_val =  5273.5
# 2020-08-19 13:30 {'COF': 2.0, 'AMD': 4.0, 'UBER': 7.0, 'MSI': 2.0, 'NET': 9.0} acc_val =  5268.4
# 2020-08-19 14:00 {'COF': 12.0, 'BRK.B': 3.0} acc_val =  5257.7
# 2020-08-19 14:30 {'AMD': 1.0, 'UBER': 3.0, 'MSI': 1.0, 'BRK.B': 3.0, 'FSLY': 2.0, 'NET': 4.0} acc_val =  5257.0
# 2020-08-19 15:00 {'AMD': 17.0} acc_val =  5253.3
# 2020-08-19 15:30 {'BRK.B': 6.0} acc_val =  5247.6
# 2020-08-20 09:30 {'BRK.B': 6.0, 'FSLY': 15.0} acc_val =  5240.3
# 2020-08-20 10:00 {'BRK.B': 6.0, 'UAL': 3.0, 'FSLY': 23.0, 'NET': 1.0} acc_val =  5288.3
# 2020-08-20 10:30 {'FSLY': 26.0, 'NET': 2.0} acc_val =  5328.5
# 2020-08-20 11:00 {'AMD': 1.0, 'MSI': 1.0, 'UAL': 8.0, 'FSLY': 27.0} acc_val =  5333.3
# 2020-08-20 11:30 {'COF': 1.0, 'AMD': 2.0, 'UBER': 3.0, 'MSI': 1.0, 'UAL': 10.0, 'FSLY': 28.0, 'NET': 2.0} acc_val =  5342.9
# 2020-08-20 12:00 {'COF': 1.0, 'MSI': 5.0} acc_val =  5279.4
# 2020-08-20 12:30 {'COF': 2.0, 'UBER': 39.0, 'UAL': 1.0, 'FSLY': 2.0, 'NET': 1.0} acc_val =  5279.4
# 2020-08-20 13:00 {'UBER': 42.0, 'FSLY': 5.0, 'NET': 4.0} acc_val =  5284.6
# 2020-08-20 13:30 {'AMD': 1.0, 'MSFT': 1.0, 'UBER': 53.0} acc_val =  5294.9
# 2020-08-20 14:00 {'MSFT': 2.0, 'UBER': 61.0, 'MSI': 1.0, 'UAL': 3.0, 'NET': 2.0} acc_val =  5316.2
# 2020-08-20 14:30 {'MSFT': 2.0, 'UBER': 82.0, 'NET': 3.0} acc_val =  5381.8
# 2020-08-20 15:00 {'AMD': 2.0, 'MSFT': 3.0, 'UAL': 4.0, 'FSLY': 2.0} acc_val =  5368.3
# 2020-08-20 15:30 {'FB': 1.0, 'COF': 2.0, 'AMD': 3.0, 'MSFT': 3.0, 'UBER': 3.0, 'MSI': 1.0, 'FSLY': 4.0, 'NET': 3.0} acc_val =  5370.1
# 2020-08-21 09:30 {'COF': 4.0, 'MSFT': 4.0, 'BRK.B': 1.0, 'UAL': 6.0} acc_val =  5362.1
# 2020-08-21 10:00 {'MSFT': 4.0, 'UBER': 9.0, 'MSI': 1.0, 'NET': 3.0} acc_val =  5359.8
# 2020-08-21 10:30 {'FB': 1.0, 'AMD': 2.0, 'MSFT': 5.0, 'UBER': 13.0, 'MSI': 2.0, 'FSLY': 2.0} acc_val =  5363.5
# 2020-08-21 11:00 {'AMD': 7.0, 'MSI': 4.0, 'NFLX': 1.0} acc_val =  5352.9
# 2020-08-21 11:30 {'MSI': 12.0} acc_val =  5347.2
# 2020-08-21 12:00 {'AMD': 1.0, 'UBER': 3.0, 'FSLY': 2.0, 'NET': 4.0} acc_val =  5346.2
# 2020-08-21 12:30 {'AMD': 12.0, 'UBER': 26.0} acc_val =  5344.5
# 2020-08-21 13:00 {'COF': 7.0, 'AMD': 17.0, 'BRK.B': 2.0} acc_val =  5346.5
# 2020-08-21 13:30 {'FB': 1.0, 'SPY': 1.0, 'COF': 11.0, 'MSI': 1.0, 'BRK.B': 3.0} acc_val =  5340.2
# 2020-08-21 14:00 {'SPY': 1.0, 'AMD': 1.0, 'MSI': 2.0, 'UAL': 4.0} acc_val =  5339.4
# 2020-08-21 14:30 {'FB': 1.0, 'SPY': 1.0, 'AMD': 3.0, 'MSFT': 1.0, 'MSI': 3.0, 'FSLY': 2.0, 'QQQ': 1.0} acc_val =  5339.7
# 2020-08-21 15:00 {'FB': 1.0, 'SPY': 1.0, 'COF': 2.0, 'AMD': 3.0, 'UBER': 4.0, 'MSI': 4.0, 'BRK.B': 1.0, 'FSLY': 4.0, 'QQQ': 1.0, 'NET': 3.0} acc_val =  5340.9
# 2020-08-21 15:30 {'SPY': 1.0, 'COF': 7.0, 'MSI': 6.0} acc_val =  5336.8
# 2020-08-24 09:30 {'FB': 1.0, 'COF': 11.0, 'MSI': 7.0, 'BRK.B': 1.0, 'UAL': 5.0} acc_val =  5350.5
# 2020-08-24 10:00 {'COF': 12.0, 'UBER': 2.0, 'MSI': 7.0, 'BRK.B': 1.0, 'UAL': 27.0} acc_val =  5365.1
# 2020-08-24 10:30 {'COF': 18.0, 'MSI': 8.0, 'BRK.B': 1.0, 'UAL': 33.0} acc_val =  5389.1
# 2020-08-24 11:00 {'COF': 19.0, 'UBER': 2.0, 'MSI': 8.0, 'BRK.B': 1.0, 'UAL': 34.0, 'NET': 1.0} acc_val =  5398.4
# 2020-08-24 11:30 {'COF': 19.0, 'UBER': 2.0, 'BRK.B': 1.0, 'UAL': 35.0, 'FSLY': 1.0, 'NET': 2.0} acc_val =  5416.8
# 2020-08-24 12:00 {'UBER': 7.0, 'BRK.B': 2.0} acc_val =  5404.6
# 2020-08-24 12:30 {'COF': 3.0, 'MSFT': 1.0, 'UBER': 14.0, 'MSI': 1.0, 'BRK.B': 3.0, 'UAL': 5.0} acc_val =  5407.6
# 2020-08-24 13:00 {'SPY': 1.0, 'AMD': 5.0, 'QQQ': 1.0} acc_val =  5402.9
# 2020-08-24 13:30 {'FB': 1.0, 'SPY': 1.0, 'UBER': 4.0, 'UAL': 5.0, 'FSLY': 5.0, 'NET': 4.0} acc_val =  5402.3
# 2020-08-24 14:00 {'SPY': 1.0, 'COF': 8.0, 'MSI': 3.0} acc_val =  5397.9
# 2020-08-24 14:30 {'COF': 13.0, 'MSI': 5.0, 'UAL': 8.0, 'FSLY': 3.0} acc_val =  5400.4
# 2020-08-24 15:00 {'COF': 14.0, 'AMD': 1.0, 'UBER': 2.0, 'MSI': 5.0, 'UAL': 10.0, 'FSLY': 4.0, 'NET': 1.0} acc_val =  5405.8
# 2020-08-24 15:30 {'COF': 15.0, 'AMD': 2.0, 'UBER': 4.0, 'MSI': 5.0, 'UAL': 12.0, 'NET': 3.0} acc_val =  5412.8
# 2020-08-25 09:30 {'MSI': 5.0, 'FSLY': 4.0, 'NET': 6.0} acc_val =  5419.8
# 2020-08-25 10:00 {'AMD': 3.0, 'MSFT': 1.0, 'FSLY': 7.0, 'NET': 10.0} acc_val =  5423.4
# 2020-08-25 10:30 {'AMD': 4.0, 'MSFT': 1.0, 'UBER': 2.0, 'FSLY': 16.0, 'NET': 12.0} acc_val =  5450.6
# 2020-08-25 11:00 {'FB': 1.0, 'AMD': 5.0} acc_val =  5437.5
# 2020-08-25 11:30 {'FSLY': 11.0, 'SHOP': 1.0} acc_val =  5435.0
# 2020-08-25 12:00 {'COF': 1.0, 'AMD': 1.0, 'UBER': 3.0, 'UAL': 2.0, 'FSLY': 16.0, 'NET': 2.0} acc_val =  5450.0
# 2020-08-25 12:30 {'COF': 2.0, 'AMD': 2.0, 'UBER': 7.0, 'UAL': 6.0, 'FSLY': 18.0, 'NET': 5.0} acc_val =  5457.9
# 2020-08-25 13:00 {'COF': 3.0, 'AMD': 3.0, 'UBER': 9.0, 'UAL': 8.0, 'NET': 6.0} acc_val =  5439.6
# 2020-08-25 13:30 {'COF': 7.0, 'UBER': 16.0, 'BRK.B': 1.0, 'UAL': 14.0, 'FSLY': 3.0} acc_val =  5440.6
# 2020-08-25 14:00 {'FB': 1.0, 'COF': 8.0, 'AMD': 1.0, 'UBER': 16.0, 'BRK.B': 1.0, 'UAL': 17.0, 'NET': 3.0} acc_val =  5440.5
# 2020-08-25 14:30 {'MSFT': 1.0, 'FSLY': 3.0, 'NET': 7.0} acc_val =  5433.2
# 2020-08-25 15:00 {'AMD': 3.0, 'MSFT': 2.0, 'UBER': 4.0, 'MSI': 1.0, 'BRK.B': 1.0, 'UAL': 5.0} acc_val =  5432.2
# 2020-08-25 15:30 {'COF': 2.0, 'AMD': 5.0, 'MSFT': 3.0, 'UBER': 10.0, 'MSI': 2.0, 'UAL': 8.0, 'NET': 5.0} acc_val =  5434.6
# 2020-08-26 09:30 {'COF': 2.0, 'MSFT': 3.0, 'UBER': 14.0, 'NFLX': 1.0, 'NET': 6.0} acc_val =  5443.8
# 2020-08-26 10:00 {'FB': 1.0, 'MSFT': 4.0, 'UBER': 17.0, 'FSLY': 1.0, 'NFLX': 1.0, 'NET': 9.0} acc_val =  5452.1
# 2020-08-26 10:30 {'FB': 2.0, 'MSFT': 4.0, 'UBER': 19.0, 'FSLY': 2.0, 'NFLX': 1.0, 'NET': 10.0} acc_val =  5476.8
# 2020-08-26 11:00 {'MSFT': 4.0, 'UBER': 21.0, 'UAL': 3.0, 'NFLX': 1.0, 'NET': 12.0} acc_val =  5483.0
# 2020-08-26 12:30 {'COF': 3.0, 'BRK.B': 1.0, 'UAL': 10.0, 'NFLX': 1.0} acc_val =  5494.8
# 2020-08-26 13:30 {'FB': 1.0, 'COF': 5.0, 'AMD': 1.0, 'MSFT': 1.0, 'MSI': 1.0} acc_val =  5496.9
# 2020-08-26 14:30 {'COF': 5.0} acc_val =  5494.0
# 2020-08-26 15:00 {'FB': 1.0, 'COF': 6.0, 'AMD': 1.0, 'MSFT': 1.0, 'UBER': 3.0, 'UAL': 2.0, 'FSLY': 2.0, 'NET': 3.0} acc_val =  5494.3
# 2020-08-26 15:30 {'FB': 2.0, 'MSFT': 2.0, 'UBER': 8.0, 'QQQ': 1.0, 'NET': 8.0} acc_val =  5496.1
# 2020-08-27 09:30 {'COF': 1.0, 'MSFT': 2.0, 'UBER': 8.0, 'UAL': 21.0, 'FSLY': 3.0} acc_val =  5488.7
# 2020-08-27 10:00 {'AMD': 1.0, 'FSLY': 5.0, 'NET': 14.0} acc_val =  5465.6
# 2020-08-27 10:30 {'COF': 2.0, 'UBER': 4.0, 'UAL': 3.0, 'FSLY': 11.0} acc_val =  5475.2
# 2020-08-27 11:00 {'COF': 2.0, 'UBER': 12.0, 'FSLY': 16.0, 'NET': 8.0} acc_val =  5485.0
# 2020-08-27 11:30 {'COF': 4.0, 'AMD': 1.0, 'UBER': 15.0, 'UAL': 6.0} acc_val =  5469.2
# 2020-08-27 12:00 {'COF': 17.0, 'UBER': 33.0} acc_val =  5469.2
# 2020-08-27 12:30 {'COF': 23.0, 'MSI': 2.0, 'BRK.B': 2.0} acc_val =  5459.8
# 2020-08-27 13:00 {'COF': 23.0, 'UBER': 2.0, 'MSI': 2.0, 'BRK.B': 2.0, 'UAL': 1.0, 'FSLY': 5.0, 'NET': 2.0} acc_val =  5463.3
# 2020-08-27 13:30 {'AMD': 1.0, 'MSI': 2.0, 'BRK.B': 2.0, 'NET': 5.0} acc_val =  5457.1
# 2020-08-27 14:00 {'COF': 1.0, 'AMD': 2.0, 'MSFT': 1.0, 'UBER': 6.0, 'BRK.B': 2.0, 'UAL': 3.0} acc_val =  5456.1
# 2020-08-27 14:30 {'COF': 5.0, 'AMD': 5.0, 'MSI': 2.0, 'BRK.B': 3.0, 'UAL': 14.0} acc_val =  5456.9
# 2020-08-27 15:00 {'COF': 7.0, 'UAL': 17.0, 'FSLY': 3.0} acc_val =  5459.0
# 2020-08-27 15:30 {'MSI': 5.0, 'NFLX': 1.0} acc_val =  5455.1
# 2020-08-28 09:30 {'COF': 2.0, 'AMD': 3.0, 'MSFT': 1.0, 'UBER': 4.0, 'MSI': 6.0, 'NFLX': 1.0, 'NET': 4.0} acc_val =  5464.9
# 2020-08-28 10:00 {'AMD': 5.0, 'UBER': 10.0, 'MSI': 7.0, 'NET': 7.0} acc_val =  5472.4
# 2020-08-28 10:30 {'MSI': 9.0, 'BRK.B': 2.0, 'UAL': 13.0} acc_val =  5462.4
# 2020-08-28 11:00 {'COF': 1.0, 'AMD': 1.0, 'UBER': 4.0, 'MSI': 9.0, 'BRK.B': 2.0, 'UAL': 15.0, 'FSLY': 1.0, 'NET': 1.0} acc_val =  5468.5
# 2020-08-28 11:30 {'COF': 2.0, 'UBER': 7.0, 'BRK.B': 2.0, 'UAL': 20.0, 'FSLY': 2.0, 'NET': 3.0} acc_val =  5468.2
# 2020-08-28 12:00 {'COF': 6.0, 'BRK.B': 3.0, 'FSLY': 8.0, 'NET': 3.0} acc_val =  5463.0
# 2020-08-28 12:30 {'COF': 8.0, 'MSI': 1.0, 'BRK.B': 4.0, 'UAL': 3.0, 'NET': 7.0} acc_val =  5468.0
# 2020-08-28 13:00 {'COF': 24.0} acc_val =  5462.3
# 2020-08-28 13:30 {'COF': 25.0, 'AMD': 1.0, 'UBER': 4.0, 'UAL': 3.0, 'FSLY': 1.0, 'NET': 2.0} acc_val =  5466.1
# 2020-08-28 14:00 {'COF': 27.0, 'AMD': 3.0, 'MSI': 1.0, 'BRK.B': 1.0, 'UAL': 9.0} acc_val =  5466.0
# 2020-08-28 14:30 {'COF': 29.0, 'AMD': 3.0, 'MSFT': 1.0, 'MSI': 2.0, 'BRK.B': 2.0, 'UAL': 12.0, 'FSLY': 1.0} acc_val =  5467.4
# 2020-08-28 15:00 {'COF': 30.0, 'AMD': 4.0, 'MSFT': 1.0, 'UBER': 2.0, 'MSI': 2.0, 'BRK.B': 2.0, 'UAL': 13.0} acc_val =  5472.3
# 2020-08-28 15:30 {'COF': 31.0, 'AMD': 4.0, 'MSFT': 1.0, 'UBER': 3.0, 'MSI': 2.0, 'UAL': 14.0, 'FSLY': 1.0} acc_val =  5482.0
# 2020-08-31 09:30 {'AMD': 6.0, 'MSFT': 1.0, 'MSI': 2.0} acc_val =  5433.3
# 2020-08-31 10:00 {'COF': 1.0, 'AMD': 9.0, 'UBER': 2.0, 'MSI': 3.0, 'FSLY': 5.0} acc_val =  5441.7
# 2020-08-31 10:30 {'AMD': 17.0, 'UBER': 2.0, 'FSLY': 6.0} acc_val =  5468.3
# 2020-08-31 11:00 {'FSLY': 18.0} acc_val =  5454.5
# 2020-08-31 11:30 {'COF': 1.0, 'AMD': 2.0, 'UBER': 5.0, 'MSI': 1.0, 'UAL': 4.0, 'FSLY': 19.0} acc_val =  5466.1
# 2020-08-31 12:00 {'AMD': 4.0, 'UBER': 8.0, 'MSI': 1.0, 'UAL': 6.0} acc_val =  5460.6
# 2020-08-31 12:30 {'COF': 1.0, 'AMD': 6.0, 'UBER': 11.0, 'MSI': 2.0, 'UAL': 10.0, 'FSLY': 1.0} acc_val =  5465.8
# 2020-08-31 13:00 {'AMD': 7.0, 'UBER': 14.0, 'MSI': 3.0, 'FSLY': 5.0} acc_val =  5467.7
# 2020-08-31 13:30 {'COF': 1.0, 'UBER': 17.0, 'UAL': 3.0, 'FSLY': 7.0} acc_val =  5468.7
# 2020-08-31 14:00 {'AMD': 3.0, 'MSI': 2.0} acc_val =  5467.0
# 2020-08-31 14:30 {'MSFT': 1.0, 'UBER': 3.0, 'MSI': 3.0, 'BRK.B': 1.0, 'UAL': 3.0, 'FSLY': 1.0} acc_val =  5465.6
# 2020-08-31 15:00 {'FB': 5.0, 'MSI': 3.0} acc_val =  5464.3
# 2020-08-31 15:30 {'MSI': 5.0, 'FSLY': 6.0, 'NET': 7.0} acc_val =  5456.2
# 2020-09-01 09:30 {'COF': 1.0, 'UBER': 1.0, 'UAL': 2.0, 'FSLY': 9.0, 'NET': 10.0, 'SHOP': 1.0} acc_val =  5486.6
# 2020-09-01 10:00 {'COF': 2.0, 'UBER': 3.0, 'UAL': 4.0, 'NET': 13.0, 'SHOP': 1.0} acc_val =  5508.0
# 2020-09-01 10:30 {'AMD': 6.0, 'MSI': 4.0} acc_val =  5491.9
# 2020-09-01 11:00 {'MSFT': 1.0, 'UBER': 8.0, 'MSI': 5.0, 'QQQ': 1.0} acc_val =  5492.0
# 2020-09-01 11:30 {'COF': 2.0, 'UBER': 11.0, 'MSI': 6.0, 'UAL': 17.0} acc_val =  5492.4
# 2020-09-01 12:00 {'AMD': 2.0, 'MSI': 7.0, 'FSLY': 2.0} acc_val =  5486.8
# 2020-09-01 12:30 {'UBER': 4.0, 'MSI': 8.0, 'BRK.B': 1.0, 'UAL': 4.0} acc_val =  5487.4
# 2020-09-01 13:00 {'AMD': 1.0, 'UBER': 7.0, 'FSLY': 1.0, 'NET': 3.0} acc_val =  5485.3
# 2020-09-01 13:30 {'SPY': 1.0, 'COF': 3.0, 'MSFT': 1.0, 'UBER': 16.0, 'QQQ': 1.0, 'NET': 9.0} acc_val =  5485.7
# 2020-09-01 14:00 {'SPY': 1.0, 'COF': 4.0, 'AMD': 2.0, 'MSFT': 1.0, 'UBER': 19.0, 'MSI': 1.0, 'UAL': 2.0, 'QQQ': 1.0} acc_val =  5488.5
# 2020-09-01 14:30 {'SPY': 1.0, 'COF': 4.0, 'MSFT': 2.0, 'MSI': 1.0, 'BRK.B': 1.0, 'UAL': 6.0, 'FSLY': 2.0, 'QQQ': 1.0} acc_val =  5487.8
# 2020-09-01 15:00 {'COF': 7.0, 'AMD': 2.0, 'BRK.B': 2.0, 'UAL': 11.0} acc_val =  5486.7
# 2020-09-01 15:30 {'COF': 8.0, 'AMD': 3.0, 'MSFT': 1.0, 'MSI': 1.0, 'BRK.B': 3.0, 'UAL': 15.0, 'NET': 4.0} acc_val =  5493.0
# 2020-09-02 09:30 {'COF': 13.0, 'MSFT': 2.0, 'MSI': 2.0, 'BRK.B': 4.0} acc_val =  5494.1
# 2020-09-02 10:00 {'AMD': 1.0, 'MSFT': 2.0, 'UBER': 2.0, 'MSI': 2.0, 'UAL': 1.0, 'FSLY': 5.0, 'NET': 1.0} acc_val =  5486.1
# 2020-09-02 10:30 {'MSI': 4.0, 'BRK.B': 2.0, 'NFLX': 1.0, 'NET': 10.0} acc_val =  5480.2
# 2020-09-02 11:00 {'MSI': 8.0} acc_val =  5471.1
# 2020-09-02 11:30 {'COF': 2.0, 'AMD': 1.0, 'BRK.B': 1.0, 'UAL': 16.0, 'FSLY': 1.0, 'NET': 3.0} acc_val =  5469.4
# 2020-09-02 12:00 {'COF': 3.0, 'AMD': 2.0, 'UBER': 7.0, 'FSLY': 3.0, 'NET': 5.0} acc_val =  5470.9
# 2020-09-02 12:30 {'AMD': 2.0, 'MSFT': 1.0, 'MSI': 1.0, 'BRK.B': 1.0, 'FSLY': 5.0} acc_val =  5469.1
# 2020-09-02 13:00 {'FB': 1.0, 'AMD': 3.0, 'MSFT': 2.0, 'UBER': 3.0, 'MSI': 2.0, 'UAL': 3.0, 'NET': 3.0} acc_val =  5469.0
# 2020-09-02 13:30 {'COF': 2.0, 'UBER': 10.0, 'MSI': 3.0, 'BRK.B': 1.0, 'FSLY': 4.0, 'NET': 7.0} acc_val =  5466.0
# 2020-09-02 14:00 {'FB': 1.0, 'AMD': 1.0, 'UBER': 14.0, 'MSI': 3.0, 'NET': 13.0} acc_val =  5468.3
# 2020-09-02 14:30 {'COF': 2.0, 'AMD': 2.0, 'UBER': 18.0, 'MSI': 3.0, 'UAL': 7.0, 'FSLY': 2.0, 'NET': 15.0} acc_val =  5472.3
# 2020-09-02 15:00 {'COF': 3.0, 'MSI': 3.0, 'UAL': 9.0, 'NET': 17.0} acc_val =  5472.4
# 2020-09-02 15:30 {'UBER': 5.0, 'BRK.B': 1.0, 'UAL': 14.0, 'FSLY': 2.0, 'NET': 21.0} acc_val =  5474.0
# 2020-09-03 09:30 {'UBER': 6.0, 'BRK.B': 1.0, 'UAL': 42.0, 'FSLY': 2.0} acc_val =  5468.0
# 2020-09-03 10:00 {} acc_val =  5413.3
# 2020-09-03 10:30 {'COF': 9.0, 'MSI': 4.0, 'NET': 17.0} acc_val =  5413.3
# 2020-09-03 11:00 {} acc_val =  5381.2
# 2020-09-03 11:30 {'COF': 2.0, 'AMD': 1.0, 'UBER': 7.0, 'MSI': 1.0, 'UAL': 12.0, 'FSLY': 1.0, 'NET': 2.0} acc_val =  5381.2
# 2020-09-03 12:00 {'FB': 1.0, 'COF': 7.0, 'MSI': 3.0, 'UAL': 26.0, 'NET': 2.0} acc_val =  5382.9
# 2020-09-03 12:30 {'UBER': 15.0, 'UAL': 40.0} acc_val =  5380.6
# 2020-09-03 13:00 {'COF': 1.0, 'AMD': 1.0, 'UBER': 17.0, 'FSLY': 1.0, 'NET': 5.0} acc_val =  5381.5
# 2020-09-03 13:30 {'FB': 3.0, 'FSLY': 9.0} acc_val =  5378.3
# 2020-09-03 14:00 {'AMD': 3.0, 'MSFT': 1.0, 'BRK.B': 1.0, 'QQQ': 1.0, 'NET': 6.0} acc_val =  5368.9
# 2020-09-03 14:30 {} acc_val =  5361.3
# 2020-09-03 15:00 {'MSI': 12.0} acc_val =  5361.3
# 2020-09-03 15:30 {'FB': 1.0, 'COF': 1.0, 'AMD': 1.0, 'UBER': 2.0, 'MSI': 12.0, 'UAL': 2.0, 'FSLY': 1.0, 'NET': 2.0} acc_val =  5373.5
# 2020-09-04 09:30 {'COF': 9.0, 'MSI': 13.0, 'BRK.B': 1.0} acc_val =  5371.1
# 2020-09-04 10:00 {'COF': 20.0} acc_val =  5362.8
# 2020-09-04 10:30 {'AMD': 4.0, 'UBER': 7.0, 'NET': 4.0} acc_val =  5344.0
# 2020-09-04 11:00 {'UBER': 31.0, 'UAL': 21.0} acc_val =  5342.7
# 2020-09-04 11:30 {'AMD': 1.0, 'UBER': 31.0, 'UAL': 21.0, 'FSLY': 13.0, 'NET': 1.0} acc_val =  5368.4
# 2020-09-04 12:00 {'COF': 1.0, 'AMD': 2.0, 'UAL': 25.0, 'FSLY': 14.0, 'NET': 2.0} acc_val =  5386.5
# 2020-09-04 12:30 {'FB': 1.0, 'COF': 3.0, 'UBER': 4.0, 'MSI': 1.0, 'BRK.B': 1.0} acc_val =  5375.6
# 2020-09-04 13:00 {'UAL': 39.0} acc_val =  5370.3
# 2020-09-04 13:30 {'COF': 1.0, 'AMD': 1.0, 'UBER': 2.0, 'UAL': 42.0, 'FSLY': 2.0, 'NET': 2.0} acc_val =  5382.8
# 2020-09-04 14:00 {'COF': 2.0, 'AMD': 2.0, 'UBER': 4.0, 'UAL': 45.0, 'FSLY': 3.0, 'NET': 4.0} acc_val =  5397.1
# 2020-09-04 14:30 {'COF': 2.0, 'AMD': 3.0, 'MSFT': 1.0, 'UBER': 5.0, 'FSLY': 4.0, 'NET': 6.0} acc_val =  5396.5
# 2020-09-04 15:00 {'COF': 3.0, 'AMD': 5.0, 'MSFT': 2.0, 'UBER': 7.0, 'UAL': 2.0, 'FSLY': 5.0, 'NET': 9.0} acc_val =  5404.3
# 2020-09-04 15:30 {'UAL': 2.0} acc_val =  5387.1
# 2020-09-08 09:30 {'AMD': 1.0, 'UBER': 6.0, 'FSLY': 17.0, 'NET': 2.0} acc_val =  5384.5
# 2020-09-08 10:00 {'AMD': 2.0, 'UBER': 11.0, 'UAL': 2.0, 'FSLY': 21.0, 'NET': 4.0} acc_val =  5422.7
# 2020-09-08 10:30 {'UAL': 25.0} acc_val =  5419.3
# 2020-09-08 11:00 {'SPY': 1.0, 'COF': 4.0, 'UBER': 8.0, 'MSI': 1.0, 'BRK.B': 1.0, 'UAL': 30.0, 'FSLY': 2.0} acc_val =  5420.8
# 2020-09-08 11:30 {'MSI': 4.0, 'BRK.B': 3.0} acc_val =  5394.8
# 2020-09-08 12:00 {'COF': 2.0, 'UBER': 5.0, 'MSI': 5.0, 'BRK.B': 4.0, 'UAL': 8.0, 'FSLY': 3.0} acc_val =  5399.9
# 2020-09-08 12:30 {'AMD': 1.0, 'UBER': 7.0, 'MSI': 5.0, 'BRK.B': 4.0, 'UAL': 9.0, 'FSLY': 4.0, 'NET': 1.0} acc_val =  5406.8
# 2020-09-08 13:00 {'SPY': 1.0, 'COF': 4.0, 'MSI': 7.0, 'BRK.B': 5.0} acc_val =  5407.9
# 2020-09-08 13:30 {'SPY': 1.0, 'AMD': 1.0, 'UBER': 3.0, 'MSI': 7.0, 'BRK.B': 5.0, 'UAL': 2.0, 'FSLY': 1.0, 'NET': 2.0} acc_val =  5410.3
# 2020-09-08 14:00 {} acc_val =  5398.3
# 2020-09-08 14:30 {'COF': 6.0, 'AMD': 5.0, 'UAL': 12.0, 'FSLY': 7.0} acc_val =  5398.3
# 2020-09-08 15:00 {'COF': 7.0, 'AMD': 6.0, 'UBER': 2.0, 'MSI': 1.0, 'FSLY': 8.0, 'NET': 4.0} acc_val =  5401.0
# 2020-09-08 15:30 {'FSLY': 22.0} acc_val =  5388.5
# 2020-09-09 09:30 {'UBER': 28.0} acc_val =  5416.5
# 2020-09-09 10:00 {'AMD': 2.0, 'FSLY': 1.0, 'NET': 14.0} acc_val =  5413.5
# 2020-09-09 10:30 {'COF': 2.0, 'AMD': 4.0, 'UAL': 11.0, 'NET': 17.0} acc_val =  5414.7
# 2020-09-09 11:00 {'SPY': 1.0, 'COF': 2.0, 'MSI': 3.0, 'BRK.B': 1.0, 'FSLY': 3.0} acc_val =  5411.8
# 2020-09-09 11:30 {'SPY': 1.0, 'COF': 4.0, 'MSFT': 1.0, 'FSLY': 5.0, 'QQQ': 1.0} acc_val =  5411.1
# 2020-09-09 12:00 {'SPY': 1.0, 'COF': 5.0, 'AMD': 3.0, 'MSFT': 1.0, 'UBER': 3.0, 'UAL': 2.0, 'FSLY': 6.0, 'QQQ': 1.0, 'NET': 3.0} acc_val =  5416.5
# 2020-09-09 12:30 {'SPY': 1.0, 'AMD': 4.0, 'MSFT': 1.0, 'UBER': 5.0, 'FSLY': 7.0, 'QQQ': 1.0, 'NET': 6.0} acc_val =  5420.9
# 2020-09-09 13:00 {'SPY': 2.0, 'COF': 4.0, 'MSI': 1.0, 'BRK.B': 1.0, 'UAL': 7.0} acc_val =  5411.3
# 2020-09-09 13:30 {'COF': 9.0, 'MSI': 3.0, 'BRK.B': 2.0, 'UAL': 16.0} acc_val =  5411.4
# 2020-09-09 14:00 {'AMD': 2.0, 'UBER': 3.0, 'FSLY': 1.0, 'NET': 3.0} acc_val =  5404.7
# 2020-09-09 14:30 {'AMD': 4.0, 'MSFT': 1.0, 'UBER': 7.0, 'MSI': 1.0, 'UAL': 5.0, 'FSLY': 3.0, 'NET': 8.0} acc_val =  5407.2
# 2020-09-09 15:00 {'COF': 1.0, 'AMD': 5.0, 'MSFT': 2.0, 'FSLY': 4.0, 'NET': 12.0} acc_val =  5412.8
# 2020-09-09 15:30 {'FSLY': 12.0, 'NFLX': 1.0} acc_val =  5402.8
# 2020-09-10 09:30 {'COF': 2.0, 'UBER': 15.0, 'MSI': 1.0, 'UAL': 4.0, 'FSLY': 13.0, 'NFLX': 1.0, 'NET': 2.0} acc_val =  5411.1
# 2020-09-10 10:00 {'FB': 1.0, 'UBER': 18.0, 'FSLY': 15.0} acc_val =  5418.2
# 2020-09-10 10:30 {} acc_val =  5394.8
# 2020-09-10 11:00 {'FB': 1.0, 'COF': 1.0, 'AMD': 2.0, 'UBER': 2.0, 'MSI': 1.0, 'UAL': 3.0, 'FSLY': 2.0, 'NET': 7.0} acc_val =  5394.8
# 2020-09-10 11:30 {'UAL': 40.0} acc_val =  5387.8
# 2020-09-10 12:00 {'BRK.B': 3.0, 'UAL': 58.0} acc_val =  5389.0
# 2020-09-10 12:30 {'AMD': 1.0, 'UBER': 5.0, 'MSI': 1.0, 'UAL': 60.0, 'FSLY': 2.0, 'NET': 3.0} acc_val =  5389.5
# 2020-09-10 13:00 {'COF': 2.0, 'UBER': 11.0, 'UAL': 63.0, 'FSLY': 3.0} acc_val =  5400.3
# 2020-09-10 13:30 {'UAL': 83.0} acc_val =  5400.6
# 2020-09-10 14:00 {} acc_val =  5382.8
# 2020-09-10 14:30 {'COF': 1.0, 'AMD': 2.0, 'MSFT': 1.0, 'UBER': 3.0, 'UAL': 2.0, 'FSLY': 2.0, 'NET': 5.0} acc_val =  5382.8
# 2020-09-10 15:00 {} acc_val =  5375.0
# 2020-09-10 15:30 {'FB': 1.0, 'AMD': 3.0, 'UAL': 8.0, 'QQQ': 1.0} acc_val =  5375.0
# 2020-09-11 09:30 {'UBER': 27.0, 'NFLX': 1.0} acc_val =  5368.8
# 2020-09-11 10:00 {'COF': 1.0, 'AMD': 1.0, 'UBER': 29.0, 'UAL': 5.0, 'FSLY': 1.0, 'NFLX': 1.0, 'NET': 2.0} acc_val =  5376.3
# 2020-09-11 10:30 {'FB': 1.0, 'MSFT': 1.0, 'UBER': 34.0, 'MSI': 1.0, 'QQQ': 1.0} acc_val =  5376.3
# 2020-09-11 11:00 {'COF': 4.0, 'UBER': 39.0, 'MSI': 3.0, 'BRK.B': 1.0, 'NET': 6.0} acc_val =  5374.1
# 2020-09-11 11:30 {'COF': 9.0, 'MSI': 5.0, 'BRK.B': 2.0} acc_val =  5366.9
# 2020-09-11 12:00 {'COF': 11.0, 'UBER': 3.0, 'MSI': 6.0, 'BRK.B': 2.0, 'UAL': 2.0, 'FSLY': 2.0, 'NET': 2.0} acc_val =  5376.7
# 2020-09-11 12:30 {'NET': 30.0} acc_val =  5367.7
# 2020-09-11 13:00 {'NFLX': 3.0} acc_val =  5361.4
# 2020-09-11 13:30 {'AMD': 2.0, 'UBER': 5.0, 'UAL': 4.0, 'FSLY': 5.0, 'NFLX': 3.0, 'NET': 3.0} acc_val =  5361.9
# 2020-09-11 14:00 {'COF': 1.0, 'AMD': 3.0, 'UBER': 7.0, 'UAL': 6.0, 'FSLY': 6.0, 'NFLX': 3.0, 'NET': 5.0} acc_val =  5373.5
# 2020-09-11 14:30 {'COF': 2.0, 'AMD': 4.0, 'UBER': 8.0, 'UAL': 8.0, 'NFLX': 3.0, 'NET': 7.0} acc_val =  5380.1
# 2020-09-11 15:00 {'COF': 3.0, 'AMD': 5.0, 'UBER': 10.0, 'NFLX': 3.0, 'NET': 9.0} acc_val =  5388.1
# 2020-09-11 15:30 {'UBER': 20.0, 'UAL': 14.0} acc_val =  5380.1
# 2582

# %%
# plt.plot(df[df['sym']=='FB']['trdingPrice'].values)
# plt.plot(df[df['sym']=='FB']['trdingPrice'].values, '-x')
df = pd.read_csv('normalized_dataset.csv', index_col=0)
df.reset_index(drop=True, inplace=True)
sym='TSLA'
plt.plot(df[df['sym']==sym]['trdingPrice'].values, '-x')
plt.show()
plt.plot(df[df['sym']==sym]['marketVolume'].values, '-x')

# %%
# Out:
#                   date   sym  marketOpen  marketHigh  marketLow  marketClose  \
# 0     2020-08-14 09:30  AAPL       0.000       0.001     -0.012       -0.008
# 1     2020-08-14 10:00  AAPL      -0.009      -0.007     -0.013       -0.013
# 2     2020-08-14 10:30  AAPL      -0.013      -0.009     -0.014       -0.013
# 3     2020-08-14 11:00  AAPL      -0.013      -0.010     -0.016       -0.010
# 4     2020-08-14 11:30  AAPL      -0.010      -0.007     -0.011       -0.008
# ...                ...   ...         ...         ...        ...          ...
# 7665  2020-07-31 13:30  UBER      -0.011      -0.011     -0.017       -0.014
# 7666  2020-07-31 14:00  UBER      -0.014      -0.011     -0.016       -0.011
# 7667  2020-07-31 14:30  UBER      -0.011      -0.008     -0.013       -0.010
# 7668  2020-07-31 15:00  UBER      -0.010      -0.006     -0.013       -0.009
# 7669  2020-07-31 15:30  UBER      -0.009      -0.000     -0.010       -0.005
#
#       marketAverage  marketVolume  marketNumberOfTrades  prevClose_0  \
# 0       5232572.800         2.251                 1.173       -0.008
# 1       2473088.702         1.068                 0.611       -0.013
# 2       2366544.349         1.024                 0.598       -0.013
# 3       2637299.672         1.143                 0.617       -0.010
# 4       2376919.098         1.025                 0.467       -0.008
# ...             ...           ...                   ...          ...
# 7665         -0.015         0.570                 0.636       -0.014
# 7666         -0.013         0.501                 0.584       -0.011
# 7667         -0.010         0.338                 0.440       -0.010
# 7668         -0.010         0.538                 0.767       -0.009
# 7669         -0.006         1.765                 2.169       -0.005
#
#       prevClose_1  prevClose_2  day_ref_val  %change  %change_next target  \
# 0             NaN          NaN       114.83   -0.827        -1.289   sell
# 1             NaN          NaN       114.83   -0.439        -0.474   sell
# 2          -0.008          NaN       114.83   -0.044         0.265    buy
# 3          -0.013          NaN       114.83    0.318         0.574    buy
# 4          -0.013       -0.008       114.83    0.255         0.660    buy
# ...           ...          ...          ...      ...           ...    ...
# 7665       -0.017       -0.013        30.40   -0.233         0.000   hold
# 7666       -0.011       -0.012        30.40    0.233         0.340    buy
# 7667       -0.014       -0.017        30.40    0.106         0.250    buy
# 7668       -0.011       -0.011        30.40    0.116         0.548    buy
# 7669       -0.010       -0.014        30.40    0.415         0.415    buy
#
#       trdingPrice
# 0         113.880
# 1         113.350
# 2         113.310
# 3         113.660
# 4         113.950
# ...           ...
# 7665       29.985
# 7666       30.055
# 7667       30.087
# 7668       30.130
# 7669       30.260
#
# [7670 rows x 17 columns]

# %%
print(my_acc.positions)
{k: v for k, v in my_acc.positions.items() if v}
# Out:
# defaultdict(<class 'int'>, {'FB': 0.0, 'SPY': 0.0, 'COF': 0.0, 'AMD': 0.0, 'MSFT': 0.0, 'UBER': 20.0, 'AMZN': 0.0, 'MSI': 0.0, 'BRK.B': 0.0, 'UAL': 14.0, 'GOOGL': 0, 'FSLY': 0.0, 'QQQ': 0.0, 'NFLX': 0.0, 'NET': 0.0, 'SHOP': 0.0})
# {'UBER': 20.0, 'UAL': 14.0}

# %%
plt.plot(df['%change'].values[:100])
plt.plot(df['%change_next'].values[:100])
